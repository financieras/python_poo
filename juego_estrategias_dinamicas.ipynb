# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/python_poo/blob/main/juego_estrategias_dinamicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Juego de Estrategias Dinámicas
#
# ## 1. Presentación del Juego: *Juego de Estrategias Dinámicas*
#
# El **Juego de Estrategias Dinámicas** es un desafío de decisiones y estrategia donde 26 jugadores compiten por obtener la mayor cantidad de puntos lanzando dados. Cada jugador adopta diferentes estrategias en función de la etapa del juego y su posición en la clasificación. El objetivo principal es acumular la mayor cantidad de puntos tras 5 rondas, utilizando estrategias que se adaptan dinámicamente a las circunstancias del juego.
#
# Cada jugador puede utilizar una estrategia **conservadora**, **media**, o **agresiva** en distintas etapas, lo que añade un componente de imprevisibilidad y emoción a cada ronda. Al final del juego, se determinará quién es el mejor estratega y el jugador con más puntos será proclamado ganador.
#
# ---
#
# ## 2. Normas del Juego
#
# 1. **Objetivo**:
#    El objetivo del juego es acumular la mayor cantidad de puntos después de 5 rondas, lanzando dados y tomando decisiones estratégicas en cada ronda sobre si continuar lanzando o detenerse.
#
# 2. **Jugadores**:
#    El juego cuenta con 26 jugadores, cada uno representado por una letra mayúscula del alfabeto (de la 'A' a la 'Z').
#
# 3. **Rondas**:
#    El juego consta de 5 rondas en total. En cada ronda, los jugadores tirarán un dado para acumular puntos. El valor de cada dado puede ser entre 1 y 6. Si el jugador obtiene un "1", pierde todos los puntos acumulados en esa ronda y no puede seguir tirando.
#
# 4. **Estrategias Dinámicas**:
#    - **Rondas 1 y 2**: Todos los jugadores utilizan una **estrategia conservadora**, lo que significa que dejarán de lanzar dados cuando acumulen 10 puntos en la ronda.
#    - **Rondas 3 y 4**:
#      - El jugador con la puntuación más baja usa una **estrategia media**, en la que sus decisiones para continuar son más riesgosas.
#      - Los demás jugadores continúan con la **estrategia conservadora**.
#    - **Ronda 5 (última ronda)**:
#      - El 50% de los jugadores con menor puntuación utilizan una **estrategia agresiva**, donde continuarán tirando hasta alcanzar 40 puntos.
#      - Los jugadores con mayor puntuación seguirán con la **estrategia conservadora**.
#
# 5. **Cálculo de Puntos**:
#    - En cada ronda, los puntos acumulados se añaden a la puntuación total del jugador, excepto cuando se tira un "1", que resulta en la pérdida de todos los puntos de esa ronda.
#
# 6. **Ganador**:
#    Al final de las 5 rondas, los jugadores se ordenarán en un ranking en función de la cantidad de puntos acumulados. El jugador con más puntos será proclamado el ganador.
#
#
#
#
#
# ## 3. Descripción del Código y el Concepto de Clases Abstractas en Python
#
# El código del **Juego de Estrategias Dinámicas** está diseñado para ilustrar cómo se pueden aplicar conceptos avanzados de Programación Orientada a Objetos (POO) en Python, especialmente el uso de **clases abstractas** y **estrategias dinámicas**.
#
# ### Clases Abstractas en Python
#
# En Python, una **clase abstracta** es una clase que no puede ser instanciada directamente y está destinada a ser utilizada como base para otras clases. Se define usando el módulo `abc` (Abstract Base Class) y debe contener al menos un método abstracto. Los métodos abstractos son aquellos que están definidos en la clase base, pero deben ser implementados por cualquier subclase que herede de ella. En nuestro caso, la clase abstracta es `Jugador`.
#
# La clase `Jugador` define dos métodos abstractos:
# - `tirar_dado()`: Este método define cómo cada jugador lanza el dado, pero su implementación específica varía según la estrategia que el jugador siga en cada momento del juego.
# - `decidir_continuar(puntos_ronda)`: Este método también es abstracto y su implementación varía según la estrategia que el jugador esté aplicando. Determina si el jugador sigue tirando el dado o si se detiene en cada ronda.
#
# Al usar clases abstractas, garantizamos que todas las subclases (`EstrategiaConservadora`, `EstrategiaMedia` y `EstrategiaAgresiva`) implementen su propia versión de estos métodos.
#
# ### Clases de Estrategia
#
# El patrón de estrategia está implementado a través de diferentes clases que representan el comportamiento de los jugadores en cada ronda:
# - **EstrategiaConservadora**: Los jugadores con esta estrategia se detienen cuando acumulan 10 puntos en una ronda.
# - **EstrategiaMedia**: Esta estrategia toma decisiones más riesgosas a medida que aumenta la puntuación de la ronda. Es usada por jugadores que están en posiciones más bajas a partir de la ronda 3.
# - **EstrategiaAgresiva**: Los jugadores bajo esta estrategia continúan tirando dados hasta acumular 40 puntos en la ronda. Se aplica a los jugadores con la puntuación más baja en la última ronda.
#
# Cada una de estas estrategias implementa los métodos `tirar_dado()` y `decidir_continuar()`, cumpliendo con los requisitos de la clase abstracta `Jugador`.
#
# ### El Juez y la Dinámica del Juego
#
# El juego está controlado por la clase `Juez`, que se encarga de gestionar las rondas y aplicar las estrategias a cada jugador. El juez controla la lógica del juego y las decisiones sobre qué estrategia debe seguir cada jugador, en función de la ronda y su posición en el ranking. A medida que avanza el juego, el juez actualiza las estrategias y permite que los jugadores cambien de comportamiento según su puntuación actual.
#
# El método principal que gestiona la dinámica del juego es `jugar_ronda()`, donde cada jugador tira el dado, acumula puntos y toma decisiones basadas en su estrategia actual. Las puntuaciones se suman al total del jugador y al final del juego, el juez proclama al ganador.
#
# ### Conclusión
#
# Este código ilustra cómo las **clases abstractas** permiten establecer un marco común para diferentes tipos de jugadores, cada uno con su estrategia particular. A través de la herencia, las subclases implementan diferentes comportamientos según el contexto, y el uso dinámico de estas estrategias permite que el juego sea más modular y flexible, adaptándose a las reglas del juego en cada ronda.

# %%
import random
from abc import ABC, abstractmethod

class Estrategia(ABC):
    """
    Clase abstracta base para las estrategias.
    """

    @abstractmethod
    def tirar_dado(self):
        pass

    @abstractmethod
    def decidir_continuar(self, puntos_ronda):
        pass


class EstrategiaConservadora(Estrategia):
    def tirar_dado(self):
        return random.randint(1, 6)

    def decidir_continuar(self, puntos_ronda):
        return puntos_ronda < 10


class EstrategiaArriesgada(Estrategia):
    def tirar_dado(self):
        return random.randint(1, 6)

    def decidir_continuar(self, puntos_ronda):
        return puntos_ronda < 20


class EstrategiaMedia(Estrategia):
    def tirar_dado(self):
        return random.randint(1, 6)

    def decidir_continuar(self, puntos_ronda):
        factor_riesgo = random.random()
        if puntos_ronda < 8:
            return True
        elif 8 <= puntos_ronda < 15:
            return factor_riesgo > 0.3
        else:
            return factor_riesgo > 0.7


class EstrategiaAgresiva(Estrategia):
    def tirar_dado(self):
        return random.randint(1, 6)

    def decidir_continuar(self, puntos_ronda):
        return puntos_ronda < 40  # Continúa hasta 40 puntos en la ronda


class Jugador:
    """
    Clase Jugador que tiene una estrategia asignada.
    """

    def __init__(self, nombre, estrategia):
        self.nombre = nombre
        self.puntuacion = 0
        self.estrategia = estrategia

    def cambiar_estrategia(self, nueva_estrategia):
        """
        Cambia la estrategia del jugador.
        """
        self.estrategia = nueva_estrategia

    def tirar_dado(self):
        return self.estrategia.tirar_dado()

    def decidir_continuar(self, puntos_ronda):
        return self.estrategia.decidir_continuar(puntos_ronda)

    def anadir_puntos(self, puntos):
        self.puntuacion += puntos


class Juez:
    """
    Clase Juez que gestiona la lógica del juego y las rondas.
    """

    def __init__(self, jugadores, rondas):
        self.jugadores = jugadores
        self.rondas = rondas

    def jugar_ronda(self, jugador):
        """
        Simula una ronda para un jugador.
        """
        puntos_ronda = 0
        while True:
            tirada = jugador.tirar_dado()
            print(f"{jugador.nombre} tira un {tirada}")
            if tirada == 1:
                print(f"{jugador.nombre} pierde los puntos de esta ronda.")
                return 0
            puntos_ronda += tirada
            print(f"Puntos acumulados en esta ronda: {puntos_ronda}")
            if not jugador.decidir_continuar(puntos_ronda):
                print(f"{jugador.nombre} decide detenerse.")
                break
            else:
                print(f"{jugador.nombre} decide continuar.")
        return puntos_ronda

    def asignar_estrategia(self, ronda):
        """
        Asigna estrategias dinámicamente a los jugadores según la ronda.
        """
        jugadores_ordenados = sorted(self.jugadores, key=lambda x: x.puntuacion)

        for jugador in self.jugadores:
            if ronda <= 2:  # Rondas 1 y 2: Todos conservadores
                jugador.cambiar_estrategia(EstrategiaConservadora())
            elif ronda == 3 or ronda == 4:  # Rondas intermedias
                if jugador == jugadores_ordenados[0]:  # El que va perdiendo usa estrategia media
                    jugador.cambiar_estrategia(EstrategiaMedia())
                else:
                    jugador.cambiar_estrategia(EstrategiaConservadora())
            else:  # Última ronda
                mitad_peor_jugadores = jugadores_ordenados[:len(jugadores_ordenados) // 2]
                if jugador in mitad_peor_jugadores:  # El 50% con menor puntuación usa estrategia agresiva
                    jugador.cambiar_estrategia(EstrategiaAgresiva())
                else:
                    jugador.cambiar_estrategia(EstrategiaConservadora())

    def juego_completo(self):
        """
        Simula el juego completo con varias rondas.
        """
        for ronda in range(1, self.rondas + 1):
            print(f"\n--- Ronda {ronda} ---")
            self.asignar_estrategia(ronda)
            for jugador in self.jugadores:
                print(f"\nTurno de {jugador.nombre}. Estrategia: {jugador.estrategia.__class__.__name__}")
                puntos = self.jugar_ronda(jugador)
                jugador.anadir_puntos(puntos)
                print(f"{jugador.nombre} suma {puntos} puntos. Total acumulado: {jugador.puntuacion}")

        print("\n--- Resultados Finales ---")
        ranking = sorted(self.jugadores, key=lambda x: x.puntuacion, reverse=True)
        for idx, jugador in enumerate(ranking, start=1):
            print(f"{idx}. {jugador.nombre}: {jugador.puntuacion} puntos")

        ganador = ranking[0]
        print(f"\n¡{ganador.nombre} gana con {ganador.puntuacion} puntos!")


if __name__ == "__main__":
    # Crear jugadores con estrategia inicial conservadora
    jugadores = [Jugador(chr(65 + i), EstrategiaConservadora()) for i in range(26)]

    # Crear juez
    juez = Juez(jugadores, rondas=5)

    # Jugar el juego
    juez.juego_completo()
# Out:
# --- Ronda 1 ---
#
# Turno de A. Estrategia: EstrategiaConservadora
# A tira un 1
# A pierde los puntos de esta ronda.
# A suma 0 puntos. Total acumulado: 0
#
# Turno de B. Estrategia: EstrategiaConservadora
# B tira un 5
# Puntos acumulados en esta ronda: 5
# B decide continuar.
# B tira un 4
# Puntos acumulados en esta ronda: 9
# B decide continuar.
# B tira un 5
# Puntos acumulados en esta ronda: 14
# B decide detenerse.
# B suma 14 puntos. Total acumulado: 14
#
# Turno de C. Estrategia: EstrategiaConservadora
# C tira un 4
# Puntos acumulados en esta ronda: 4
# C decide continuar.
# C tira un 3
# Puntos acumulados en esta ronda: 7
# C decide continuar.
# C tira un 4
# Puntos acumulados en esta ronda: 11
# C decide detenerse.
# C suma 11 puntos. Total acumulado: 11
#
# Turno de D. Estrategia: EstrategiaConservadora
# D tira un 3
# Puntos acumulados en esta ronda: 3
# D decide continuar.
# D tira un 4
# Puntos acumulados en esta ronda: 7
# D decide continuar.
# D tira un 1
# D pierde los puntos de esta ronda.
# D suma 0 puntos. Total acumulado: 0
#
# Turno de E. Estrategia: EstrategiaConservadora
# E tira un 6
# Puntos acumulados en esta ronda: 6
# E decide continuar.
# E tira un 2
# Puntos acumulados en esta ronda: 8
# E decide continuar.
# E tira un 5
# Puntos acumulados en esta ronda: 13
# E decide detenerse.
# E suma 13 puntos. Total acumulado: 13
#
# Turno de F. Estrategia: EstrategiaConservadora
# F tira un 6
# Puntos acumulados en esta ronda: 6
# F decide continuar.
# F tira un 6
# Puntos acumulados en esta ronda: 12
# F decide detenerse.
# F suma 12 puntos. Total acumulado: 12
#
# Turno de G. Estrategia: EstrategiaConservadora
# G tira un 6
# Puntos acumulados en esta ronda: 6
# G decide continuar.
# G tira un 2
# Puntos acumulados en esta ronda: 8
# G decide continuar.
# G tira un 3
# Puntos acumulados en esta ronda: 11
# G decide detenerse.
# G suma 11 puntos. Total acumulado: 11
#
# Turno de H. Estrategia: EstrategiaConservadora
# H tira un 2
# Puntos acumulados en esta ronda: 2
# H decide continuar.
# H tira un 4
# Puntos acumulados en esta ronda: 6
# H decide continuar.
# H tira un 3
# Puntos acumulados en esta ronda: 9
# H decide continuar.
# H tira un 3
# Puntos acumulados en esta ronda: 12
# H decide detenerse.
# H suma 12 puntos. Total acumulado: 12
#
# Turno de I. Estrategia: EstrategiaConservadora
# I tira un 2
# Puntos acumulados en esta ronda: 2
# I decide continuar.
# I tira un 6
# Puntos acumulados en esta ronda: 8
# I decide continuar.
# I tira un 3
# Puntos acumulados en esta ronda: 11
# I decide detenerse.
# I suma 11 puntos. Total acumulado: 11
#
# Turno de J. Estrategia: EstrategiaConservadora
# J tira un 2
# Puntos acumulados en esta ronda: 2
# J decide continuar.
# J tira un 1
# J pierde los puntos de esta ronda.
# J suma 0 puntos. Total acumulado: 0
#
# Turno de K. Estrategia: EstrategiaConservadora
# K tira un 5
# Puntos acumulados en esta ronda: 5
# K decide continuar.
# K tira un 5
# Puntos acumulados en esta ronda: 10
# K decide detenerse.
# K suma 10 puntos. Total acumulado: 10
#
# Turno de L. Estrategia: EstrategiaConservadora
# L tira un 4
# Puntos acumulados en esta ronda: 4
# L decide continuar.
# L tira un 1
# L pierde los puntos de esta ronda.
# L suma 0 puntos. Total acumulado: 0
#
# Turno de M. Estrategia: EstrategiaConservadora
# M tira un 3
# Puntos acumulados en esta ronda: 3
# M decide continuar.
# M tira un 2
# Puntos acumulados en esta ronda: 5
# M decide continuar.
# M tira un 3
# Puntos acumulados en esta ronda: 8
# M decide continuar.
# M tira un 1
# M pierde los puntos de esta ronda.
# M suma 0 puntos. Total acumulado: 0
#
# Turno de N. Estrategia: EstrategiaConservadora
# N tira un 6
# Puntos acumulados en esta ronda: 6
# N decide continuar.
# N tira un 2
# Puntos acumulados en esta ronda: 8
# N decide continuar.
# N tira un 2
# Puntos acumulados en esta ronda: 10
# N decide detenerse.
# N suma 10 puntos. Total acumulado: 10
#
# Turno de O. Estrategia: EstrategiaConservadora
# O tira un 6
# Puntos acumulados en esta ronda: 6
# O decide continuar.
# O tira un 2
# Puntos acumulados en esta ronda: 8
# O decide continuar.
# O tira un 1
# O pierde los puntos de esta ronda.
# O suma 0 puntos. Total acumulado: 0
#
# Turno de P. Estrategia: EstrategiaConservadora
# P tira un 5
# Puntos acumulados en esta ronda: 5
# P decide continuar.
# P tira un 4
# Puntos acumulados en esta ronda: 9
# P decide continuar.
# P tira un 5
# Puntos acumulados en esta ronda: 14
# P decide detenerse.
# P suma 14 puntos. Total acumulado: 14
#
# Turno de Q. Estrategia: EstrategiaConservadora
# Q tira un 3
# Puntos acumulados en esta ronda: 3
# Q decide continuar.
# Q tira un 3
# Puntos acumulados en esta ronda: 6
# Q decide continuar.
# Q tira un 4
# Puntos acumulados en esta ronda: 10
# Q decide detenerse.
# Q suma 10 puntos. Total acumulado: 10
#
# Turno de R. Estrategia: EstrategiaConservadora
# R tira un 5
# Puntos acumulados en esta ronda: 5
# R decide continuar.
# R tira un 4
# Puntos acumulados en esta ronda: 9
# R decide continuar.
# R tira un 5
# Puntos acumulados en esta ronda: 14
# R decide detenerse.
# R suma 14 puntos. Total acumulado: 14
#
# Turno de S. Estrategia: EstrategiaConservadora
# S tira un 3
# Puntos acumulados en esta ronda: 3
# S decide continuar.
# S tira un 1
# S pierde los puntos de esta ronda.
# S suma 0 puntos. Total acumulado: 0
#
# Turno de T. Estrategia: EstrategiaConservadora
# T tira un 5
# Puntos acumulados en esta ronda: 5
# T decide continuar.
# T tira un 1
# T pierde los puntos de esta ronda.
# T suma 0 puntos. Total acumulado: 0
#
# Turno de U. Estrategia: EstrategiaConservadora
# U tira un 4
# Puntos acumulados en esta ronda: 4
# U decide continuar.
# U tira un 2
# Puntos acumulados en esta ronda: 6
# U decide continuar.
# U tira un 6
# Puntos acumulados en esta ronda: 12
# U decide detenerse.
# U suma 12 puntos. Total acumulado: 12
#
# Turno de V. Estrategia: EstrategiaConservadora
# V tira un 3
# Puntos acumulados en esta ronda: 3
# V decide continuar.
# V tira un 3
# Puntos acumulados en esta ronda: 6
# V decide continuar.
# V tira un 1
# V pierde los puntos de esta ronda.
# V suma 0 puntos. Total acumulado: 0
#
# Turno de W. Estrategia: EstrategiaConservadora
# W tira un 5
# Puntos acumulados en esta ronda: 5
# W decide continuar.
# W tira un 3
# Puntos acumulados en esta ronda: 8
# W decide continuar.
# W tira un 1
# W pierde los puntos de esta ronda.
# W suma 0 puntos. Total acumulado: 0
#
# Turno de X. Estrategia: EstrategiaConservadora
# X tira un 3
# Puntos acumulados en esta ronda: 3
# X decide continuar.
# X tira un 5
# Puntos acumulados en esta ronda: 8
# X decide continuar.
# X tira un 4
# Puntos acumulados en esta ronda: 12
# X decide detenerse.
# X suma 12 puntos. Total acumulado: 12
#
# Turno de Y. Estrategia: EstrategiaConservadora
# Y tira un 3
# Puntos acumulados en esta ronda: 3
# Y decide continuar.
# Y tira un 6
# Puntos acumulados en esta ronda: 9
# Y decide continuar.
# Y tira un 3
# Puntos acumulados en esta ronda: 12
# Y decide detenerse.
# Y suma 12 puntos. Total acumulado: 12
#
# Turno de Z. Estrategia: EstrategiaConservadora
# Z tira un 3
# Puntos acumulados en esta ronda: 3
# Z decide continuar.
# Z tira un 5
# Puntos acumulados en esta ronda: 8
# Z decide continuar.
# Z tira un 3
# Puntos acumulados en esta ronda: 11
# Z decide detenerse.
# Z suma 11 puntos. Total acumulado: 11
#
# --- Ronda 2 ---
#
# Turno de A. Estrategia: EstrategiaConservadora
# A tira un 2
# Puntos acumulados en esta ronda: 2
# A decide continuar.
# A tira un 3
# Puntos acumulados en esta ronda: 5
# A decide continuar.
# A tira un 2
# Puntos acumulados en esta ronda: 7
# A decide continuar.
# A tira un 3
# Puntos acumulados en esta ronda: 10
# A decide detenerse.
# A suma 10 puntos. Total acumulado: 10
#
# Turno de B. Estrategia: EstrategiaConservadora
# B tira un 6
# Puntos acumulados en esta ronda: 6
# B decide continuar.
# B tira un 1
# B pierde los puntos de esta ronda.
# B suma 0 puntos. Total acumulado: 14
#
# Turno de C. Estrategia: EstrategiaConservadora
# C tira un 6
# Puntos acumulados en esta ronda: 6
# C decide continuar.
# C tira un 5
# Puntos acumulados en esta ronda: 11
# C decide detenerse.
# C suma 11 puntos. Total acumulado: 22
#
# Turno de D. Estrategia: EstrategiaConservadora
# D tira un 6
# Puntos acumulados en esta ronda: 6
# D decide continuar.
# D tira un 4
# Puntos acumulados en esta ronda: 10
# D decide detenerse.
# D suma 10 puntos. Total acumulado: 10
#
# Turno de E. Estrategia: EstrategiaConservadora
# E tira un 1
# E pierde los puntos de esta ronda.
# E suma 0 puntos. Total acumulado: 13
#
# Turno de F. Estrategia: EstrategiaConservadora
# F tira un 5
# Puntos acumulados en esta ronda: 5
# F decide continuar.
# F tira un 1
# F pierde los puntos de esta ronda.
# F suma 0 puntos. Total acumulado: 12
#
# Turno de G. Estrategia: EstrategiaConservadora
# G tira un 6
# Puntos acumulados en esta ronda: 6
# G decide continuar.
# G tira un 6
# Puntos acumulados en esta ronda: 12
# G decide detenerse.
# G suma 12 puntos. Total acumulado: 23
#
# Turno de H. Estrategia: EstrategiaConservadora
# H tira un 5
# Puntos acumulados en esta ronda: 5
# H decide continuar.
# H tira un 6
# Puntos acumulados en esta ronda: 11
# H decide detenerse.
# H suma 11 puntos. Total acumulado: 23
#
# Turno de I. Estrategia: EstrategiaConservadora
# I tira un 2
# Puntos acumulados en esta ronda: 2
# I decide continuar.
# I tira un 4
# Puntos acumulados en esta ronda: 6
# I decide continuar.
# I tira un 2
# Puntos acumulados en esta ronda: 8
# I decide continuar.
# I tira un 2
# Puntos acumulados en esta ronda: 10
# I decide detenerse.
# I suma 10 puntos. Total acumulado: 21
#
# Turno de J. Estrategia: EstrategiaConservadora
# J tira un 3
# Puntos acumulados en esta ronda: 3
# J decide continuar.
# J tira un 1
# J pierde los puntos de esta ronda.
# J suma 0 puntos. Total acumulado: 0
#
# Turno de K. Estrategia: EstrategiaConservadora
# K tira un 1
# K pierde los puntos de esta ronda.
# K suma 0 puntos. Total acumulado: 10
#
# Turno de L. Estrategia: EstrategiaConservadora
# L tira un 5
# Puntos acumulados en esta ronda: 5
# L decide continuar.
# L tira un 1
# L pierde los puntos de esta ronda.
# L suma 0 puntos. Total acumulado: 0
#
# Turno de M. Estrategia: EstrategiaConservadora
# M tira un 1
# M pierde los puntos de esta ronda.
# M suma 0 puntos. Total acumulado: 0
#
# Turno de N. Estrategia: EstrategiaConservadora
# N tira un 6
# Puntos acumulados en esta ronda: 6
# N decide continuar.
# N tira un 6
# Puntos acumulados en esta ronda: 12
# N decide detenerse.
# N suma 12 puntos. Total acumulado: 22
#
# Turno de O. Estrategia: EstrategiaConservadora
# O tira un 5
# Puntos acumulados en esta ronda: 5
# O decide continuar.
# O tira un 2
# Puntos acumulados en esta ronda: 7
# O decide continuar.
# O tira un 5
# Puntos acumulados en esta ronda: 12
# O decide detenerse.
# O suma 12 puntos. Total acumulado: 12
#
# Turno de P. Estrategia: EstrategiaConservadora
# P tira un 4
# Puntos acumulados en esta ronda: 4
# P decide continuar.
# P tira un 4
# Puntos acumulados en esta ronda: 8
# P decide continuar.
# P tira un 4
# Puntos acumulados en esta ronda: 12
# P decide detenerse.
# P suma 12 puntos. Total acumulado: 26
#
# Turno de Q. Estrategia: EstrategiaConservadora
# Q tira un 2
# Puntos acumulados en esta ronda: 2
# Q decide continuar.
# Q tira un 5
# Puntos acumulados en esta ronda: 7
# Q decide continuar.
# Q tira un 4
# Puntos acumulados en esta ronda: 11
# Q decide detenerse.
# Q suma 11 puntos. Total acumulado: 21
#
# Turno de R. Estrategia: EstrategiaConservadora
# R tira un 1
# R pierde los puntos de esta ronda.
# R suma 0 puntos. Total acumulado: 14
#
# Turno de S. Estrategia: EstrategiaConservadora
# S tira un 3
# Puntos acumulados en esta ronda: 3
# S decide continuar.
# S tira un 6
# Puntos acumulados en esta ronda: 9
# S decide continuar.
# S tira un 6
# Puntos acumulados en esta ronda: 15
# S decide detenerse.
# S suma 15 puntos. Total acumulado: 15
#
# Turno de T. Estrategia: EstrategiaConservadora
# T tira un 3
# Puntos acumulados en esta ronda: 3
# T decide continuar.
# T tira un 6
# Puntos acumulados en esta ronda: 9
# T decide continuar.
# T tira un 1
# T pierde los puntos de esta ronda.
# T suma 0 puntos. Total acumulado: 0
#
# Turno de U. Estrategia: EstrategiaConservadora
# U tira un 2
# Puntos acumulados en esta ronda: 2
# U decide continuar.
# U tira un 6
# Puntos acumulados en esta ronda: 8
# U decide continuar.
# U tira un 5
# Puntos acumulados en esta ronda: 13
# U decide detenerse.
# U suma 13 puntos. Total acumulado: 25
#
# Turno de V. Estrategia: EstrategiaConservadora
# V tira un 2
# Puntos acumulados en esta ronda: 2
# V decide continuar.
# V tira un 5
# Puntos acumulados en esta ronda: 7
# V decide continuar.
# V tira un 1
# V pierde los puntos de esta ronda.
# V suma 0 puntos. Total acumulado: 0
#
# Turno de W. Estrategia: EstrategiaConservadora
# W tira un 2
# Puntos acumulados en esta ronda: 2
# W decide continuar.
# W tira un 3
# Puntos acumulados en esta ronda: 5
# W decide continuar.
# W tira un 1
# W pierde los puntos de esta ronda.
# W suma 0 puntos. Total acumulado: 0
#
# Turno de X. Estrategia: EstrategiaConservadora
# X tira un 4
# Puntos acumulados en esta ronda: 4
# X decide continuar.
# X tira un 3
# Puntos acumulados en esta ronda: 7
# X decide continuar.
# X tira un 1
# X pierde los puntos de esta ronda.
# X suma 0 puntos. Total acumulado: 12
#
# Turno de Y. Estrategia: EstrategiaConservadora
# Y tira un 2
# Puntos acumulados en esta ronda: 2
# Y decide continuar.
# Y tira un 3
# Puntos acumulados en esta ronda: 5
# Y decide continuar.
# Y tira un 1
# Y pierde los puntos de esta ronda.
# Y suma 0 puntos. Total acumulado: 12
#
# Turno de Z. Estrategia: EstrategiaConservadora
# Z tira un 6
# Puntos acumulados en esta ronda: 6
# Z decide continuar.
# Z tira un 2
# Puntos acumulados en esta ronda: 8
# Z decide continuar.
# Z tira un 5
# Puntos acumulados en esta ronda: 13
# Z decide detenerse.
# Z suma 13 puntos. Total acumulado: 24
#
# --- Ronda 3 ---
#
# Turno de A. Estrategia: EstrategiaConservadora
# A tira un 1
# A pierde los puntos de esta ronda.
# A suma 0 puntos. Total acumulado: 10
#
# Turno de B. Estrategia: EstrategiaConservadora
# B tira un 3
# Puntos acumulados en esta ronda: 3
# B decide continuar.
# B tira un 6
# Puntos acumulados en esta ronda: 9
# B decide continuar.
# B tira un 1
# B pierde los puntos de esta ronda.
# B suma 0 puntos. Total acumulado: 14
#
# Turno de C. Estrategia: EstrategiaConservadora
# C tira un 3
# Puntos acumulados en esta ronda: 3
# C decide continuar.
# C tira un 2
# Puntos acumulados en esta ronda: 5
# C decide continuar.
# C tira un 6
# Puntos acumulados en esta ronda: 11
# C decide detenerse.
# C suma 11 puntos. Total acumulado: 33
#
# Turno de D. Estrategia: EstrategiaConservadora
# D tira un 3
# Puntos acumulados en esta ronda: 3
# D decide continuar.
# D tira un 2
# Puntos acumulados en esta ronda: 5
# D decide continuar.
# D tira un 6
# Puntos acumulados en esta ronda: 11
# D decide detenerse.
# D suma 11 puntos. Total acumulado: 21
#
# Turno de E. Estrategia: EstrategiaConservadora
# E tira un 4
# Puntos acumulados en esta ronda: 4
# E decide continuar.
# E tira un 3
# Puntos acumulados en esta ronda: 7
# E decide continuar.
# E tira un 1
# E pierde los puntos de esta ronda.
# E suma 0 puntos. Total acumulado: 13
#
# Turno de F. Estrategia: EstrategiaConservadora
# F tira un 6
# Puntos acumulados en esta ronda: 6
# F decide continuar.
# F tira un 1
# F pierde los puntos de esta ronda.
# F suma 0 puntos. Total acumulado: 12
#
# Turno de G. Estrategia: EstrategiaConservadora
# G tira un 2
# Puntos acumulados en esta ronda: 2
# G decide continuar.
# G tira un 5
# Puntos acumulados en esta ronda: 7
# G decide continuar.
# G tira un 6
# Puntos acumulados en esta ronda: 13
# G decide detenerse.
# G suma 13 puntos. Total acumulado: 36
#
# Turno de H. Estrategia: EstrategiaConservadora
# H tira un 3
# Puntos acumulados en esta ronda: 3
# H decide continuar.
# H tira un 2
# Puntos acumulados en esta ronda: 5
# H decide continuar.
# H tira un 4
# Puntos acumulados en esta ronda: 9
# H decide continuar.
# H tira un 6
# Puntos acumulados en esta ronda: 15
# H decide detenerse.
# H suma 15 puntos. Total acumulado: 38
#
# Turno de I. Estrategia: EstrategiaConservadora
# I tira un 5
# Puntos acumulados en esta ronda: 5
# I decide continuar.
# I tira un 4
# Puntos acumulados en esta ronda: 9
# I decide continuar.
# I tira un 5
# Puntos acumulados en esta ronda: 14
# I decide detenerse.
# I suma 14 puntos. Total acumulado: 35
#
# Turno de J. Estrategia: EstrategiaMedia
# J tira un 5
# Puntos acumulados en esta ronda: 5
# J decide continuar.
# J tira un 2
# Puntos acumulados en esta ronda: 7
# J decide continuar.
# J tira un 3
# Puntos acumulados en esta ronda: 10
# J decide continuar.
# J tira un 6
# Puntos acumulados en esta ronda: 16
# J decide continuar.
# J tira un 3
# Puntos acumulados en esta ronda: 19
# J decide detenerse.
# J suma 19 puntos. Total acumulado: 19
#
# Turno de K. Estrategia: EstrategiaConservadora
# K tira un 2
# Puntos acumulados en esta ronda: 2
# K decide continuar.
# K tira un 6
# Puntos acumulados en esta ronda: 8
# K decide continuar.
# K tira un 6
# Puntos acumulados en esta ronda: 14
# K decide detenerse.
# K suma 14 puntos. Total acumulado: 24
#
# Turno de L. Estrategia: EstrategiaConservadora
# L tira un 5
# Puntos acumulados en esta ronda: 5
# L decide continuar.
# L tira un 6
# Puntos acumulados en esta ronda: 11
# L decide detenerse.
# L suma 11 puntos. Total acumulado: 11
#
# Turno de M. Estrategia: EstrategiaConservadora
# M tira un 6
# Puntos acumulados en esta ronda: 6
# M decide continuar.
# M tira un 3
# Puntos acumulados en esta ronda: 9
# M decide continuar.
# M tira un 3
# Puntos acumulados en esta ronda: 12
# M decide detenerse.
# M suma 12 puntos. Total acumulado: 12
#
# Turno de N. Estrategia: EstrategiaConservadora
# N tira un 2
# Puntos acumulados en esta ronda: 2
# N decide continuar.
# N tira un 2
# Puntos acumulados en esta ronda: 4
# N decide continuar.
# N tira un 6
# Puntos acumulados en esta ronda: 10
# N decide detenerse.
# N suma 10 puntos. Total acumulado: 32
#
# Turno de O. Estrategia: EstrategiaConservadora
# O tira un 2
# Puntos acumulados en esta ronda: 2
# O decide continuar.
# O tira un 6
# Puntos acumulados en esta ronda: 8
# O decide continuar.
# O tira un 6
# Puntos acumulados en esta ronda: 14
# O decide detenerse.
# O suma 14 puntos. Total acumulado: 26
#
# Turno de P. Estrategia: EstrategiaConservadora
# P tira un 4
# Puntos acumulados en esta ronda: 4
# P decide continuar.
# P tira un 1
# P pierde los puntos de esta ronda.
# P suma 0 puntos. Total acumulado: 26
#
# Turno de Q. Estrategia: EstrategiaConservadora
# Q tira un 4
# Puntos acumulados en esta ronda: 4
# Q decide continuar.
# Q tira un 2
# Puntos acumulados en esta ronda: 6
# Q decide continuar.
# Q tira un 1
# Q pierde los puntos de esta ronda.
# Q suma 0 puntos. Total acumulado: 21
#
# Turno de R. Estrategia: EstrategiaConservadora
# R tira un 4
# Puntos acumulados en esta ronda: 4
# R decide continuar.
# R tira un 3
# Puntos acumulados en esta ronda: 7
# R decide continuar.
# R tira un 4
# Puntos acumulados en esta ronda: 11
# R decide detenerse.
# R suma 11 puntos. Total acumulado: 25
#
# Turno de S. Estrategia: EstrategiaConservadora
# S tira un 5
# Puntos acumulados en esta ronda: 5
# S decide continuar.
# S tira un 5
# Puntos acumulados en esta ronda: 10
# S decide detenerse.
# S suma 10 puntos. Total acumulado: 25
#
# Turno de T. Estrategia: EstrategiaConservadora
# T tira un 6
# Puntos acumulados en esta ronda: 6
# T decide continuar.
# T tira un 6
# Puntos acumulados en esta ronda: 12
# T decide detenerse.
# T suma 12 puntos. Total acumulado: 12
#
# Turno de U. Estrategia: EstrategiaConservadora
# U tira un 3
# Puntos acumulados en esta ronda: 3
# U decide continuar.
# U tira un 6
# Puntos acumulados en esta ronda: 9
# U decide continuar.
# U tira un 2
# Puntos acumulados en esta ronda: 11
# U decide detenerse.
# U suma 11 puntos. Total acumulado: 36
#
# Turno de V. Estrategia: EstrategiaConservadora
# V tira un 2
# Puntos acumulados en esta ronda: 2
# V decide continuar.
# V tira un 3
# Puntos acumulados en esta ronda: 5
# V decide continuar.
# V tira un 1
# V pierde los puntos de esta ronda.
# V suma 0 puntos. Total acumulado: 0
#
# Turno de W. Estrategia: EstrategiaConservadora
# W tira un 5
# Puntos acumulados en esta ronda: 5
# W decide continuar.
# W tira un 2
# Puntos acumulados en esta ronda: 7
# W decide continuar.
# W tira un 2
# Puntos acumulados en esta ronda: 9
# W decide continuar.
# W tira un 5
# Puntos acumulados en esta ronda: 14
# W decide detenerse.
# W suma 14 puntos. Total acumulado: 14
#
# Turno de X. Estrategia: EstrategiaConservadora
# X tira un 1
# X pierde los puntos de esta ronda.
# X suma 0 puntos. Total acumulado: 12
#
# Turno de Y. Estrategia: EstrategiaConservadora
# Y tira un 4
# Puntos acumulados en esta ronda: 4
# Y decide continuar.
# Y tira un 3
# Puntos acumulados en esta ronda: 7
# Y decide continuar.
# Y tira un 1
# Y pierde los puntos de esta ronda.
# Y suma 0 puntos. Total acumulado: 12
#
# Turno de Z. Estrategia: EstrategiaConservadora
# Z tira un 3
# Puntos acumulados en esta ronda: 3
# Z decide continuar.
# Z tira un 6
# Puntos acumulados en esta ronda: 9
# Z decide continuar.
# Z tira un 4
# Puntos acumulados en esta ronda: 13
# Z decide detenerse.
# Z suma 13 puntos. Total acumulado: 37
#
# --- Ronda 4 ---
#
# Turno de A. Estrategia: EstrategiaConservadora
# A tira un 6
# Puntos acumulados en esta ronda: 6
# A decide continuar.
# A tira un 3
# Puntos acumulados en esta ronda: 9
# A decide continuar.
# A tira un 1
# A pierde los puntos de esta ronda.
# A suma 0 puntos. Total acumulado: 10
#
# Turno de B. Estrategia: EstrategiaConservadora
# B tira un 5
# Puntos acumulados en esta ronda: 5
# B decide continuar.
# B tira un 4
# Puntos acumulados en esta ronda: 9
# B decide continuar.
# B tira un 4
# Puntos acumulados en esta ronda: 13
# B decide detenerse.
# B suma 13 puntos. Total acumulado: 27
#
# Turno de C. Estrategia: EstrategiaConservadora
# C tira un 2
# Puntos acumulados en esta ronda: 2
# C decide continuar.
# C tira un 3
# Puntos acumulados en esta ronda: 5
# C decide continuar.
# C tira un 6
# Puntos acumulados en esta ronda: 11
# C decide detenerse.
# C suma 11 puntos. Total acumulado: 44
#
# Turno de D. Estrategia: EstrategiaConservadora
# D tira un 2
# Puntos acumulados en esta ronda: 2
# D decide continuar.
# D tira un 2
# Puntos acumulados en esta ronda: 4
# D decide continuar.
# D tira un 3
# Puntos acumulados en esta ronda: 7
# D decide continuar.
# D tira un 6
# Puntos acumulados en esta ronda: 13
# D decide detenerse.
# D suma 13 puntos. Total acumulado: 34
#
# Turno de E. Estrategia: EstrategiaConservadora
# E tira un 6
# Puntos acumulados en esta ronda: 6
# E decide continuar.
# E tira un 3
# Puntos acumulados en esta ronda: 9
# E decide continuar.
# E tira un 6
# Puntos acumulados en esta ronda: 15
# E decide detenerse.
# E suma 15 puntos. Total acumulado: 28
#
# Turno de F. Estrategia: EstrategiaConservadora
# F tira un 2
# Puntos acumulados en esta ronda: 2
# F decide continuar.
# F tira un 3
# Puntos acumulados en esta ronda: 5
# F decide continuar.
# F tira un 2
# Puntos acumulados en esta ronda: 7
# F decide continuar.
# F tira un 3
# Puntos acumulados en esta ronda: 10
# F decide detenerse.
# F suma 10 puntos. Total acumulado: 22
#
# Turno de G. Estrategia: EstrategiaConservadora
# G tira un 5
# Puntos acumulados en esta ronda: 5
# G decide continuar.
# G tira un 6
# Puntos acumulados en esta ronda: 11
# G decide detenerse.
# G suma 11 puntos. Total acumulado: 47
#
# Turno de H. Estrategia: EstrategiaConservadora
# H tira un 2
# Puntos acumulados en esta ronda: 2
# H decide continuar.
# H tira un 4
# Puntos acumulados en esta ronda: 6
# H decide continuar.
# H tira un 5
# Puntos acumulados en esta ronda: 11
# H decide detenerse.
# H suma 11 puntos. Total acumulado: 49
#
# Turno de I. Estrategia: EstrategiaConservadora
# I tira un 3
# Puntos acumulados en esta ronda: 3
# I decide continuar.
# I tira un 5
# Puntos acumulados en esta ronda: 8
# I decide continuar.
# I tira un 2
# Puntos acumulados en esta ronda: 10
# I decide detenerse.
# I suma 10 puntos. Total acumulado: 45
#
# Turno de J. Estrategia: EstrategiaConservadora
# J tira un 3
# Puntos acumulados en esta ronda: 3
# J decide continuar.
# J tira un 4
# Puntos acumulados en esta ronda: 7
# J decide continuar.
# J tira un 1
# J pierde los puntos de esta ronda.
# J suma 0 puntos. Total acumulado: 19
#
# Turno de K. Estrategia: EstrategiaConservadora
# K tira un 3
# Puntos acumulados en esta ronda: 3
# K decide continuar.
# K tira un 1
# K pierde los puntos de esta ronda.
# K suma 0 puntos. Total acumulado: 24
#
# Turno de L. Estrategia: EstrategiaConservadora
# L tira un 2
# Puntos acumulados en esta ronda: 2
# L decide continuar.
# L tira un 1
# L pierde los puntos de esta ronda.
# L suma 0 puntos. Total acumulado: 11
#
# Turno de M. Estrategia: EstrategiaConservadora
# M tira un 2
# Puntos acumulados en esta ronda: 2
# M decide continuar.
# M tira un 4
# Puntos acumulados en esta ronda: 6
# M decide continuar.
# M tira un 3
# Puntos acumulados en esta ronda: 9
# M decide continuar.
# M tira un 1
# M pierde los puntos de esta ronda.
# M suma 0 puntos. Total acumulado: 12
#
# Turno de N. Estrategia: EstrategiaConservadora
# N tira un 2
# Puntos acumulados en esta ronda: 2
# N decide continuar.
# N tira un 2
# Puntos acumulados en esta ronda: 4
# N decide continuar.
# N tira un 6
# Puntos acumulados en esta ronda: 10
# N decide detenerse.
# N suma 10 puntos. Total acumulado: 42
#
# Turno de O. Estrategia: EstrategiaConservadora
# O tira un 4
# Puntos acumulados en esta ronda: 4
# O decide continuar.
# O tira un 6
# Puntos acumulados en esta ronda: 10
# O decide detenerse.
# O suma 10 puntos. Total acumulado: 36
#
# Turno de P. Estrategia: EstrategiaConservadora
# P tira un 3
# Puntos acumulados en esta ronda: 3
# P decide continuar.
# P tira un 1
# P pierde los puntos de esta ronda.
# P suma 0 puntos. Total acumulado: 26
#
# Turno de Q. Estrategia: EstrategiaConservadora
# Q tira un 5
# Puntos acumulados en esta ronda: 5
# Q decide continuar.
# Q tira un 4
# Puntos acumulados en esta ronda: 9
# Q decide continuar.
# Q tira un 3
# Puntos acumulados en esta ronda: 12
# Q decide detenerse.
# Q suma 12 puntos. Total acumulado: 33
#
# Turno de R. Estrategia: EstrategiaConservadora
# R tira un 1
# R pierde los puntos de esta ronda.
# R suma 0 puntos. Total acumulado: 25
#
# Turno de S. Estrategia: EstrategiaConservadora
# S tira un 5
# Puntos acumulados en esta ronda: 5
# S decide continuar.
# S tira un 3
# Puntos acumulados en esta ronda: 8
# S decide continuar.
# S tira un 1
# S pierde los puntos de esta ronda.
# S suma 0 puntos. Total acumulado: 25
#
# Turno de T. Estrategia: EstrategiaConservadora
# T tira un 2
# Puntos acumulados en esta ronda: 2
# T decide continuar.
# T tira un 4
# Puntos acumulados en esta ronda: 6
# T decide continuar.
# T tira un 2
# Puntos acumulados en esta ronda: 8
# T decide continuar.
# T tira un 5
# Puntos acumulados en esta ronda: 13
# T decide detenerse.
# T suma 13 puntos. Total acumulado: 25
#
# Turno de U. Estrategia: EstrategiaConservadora
# U tira un 2
# Puntos acumulados en esta ronda: 2
# U decide continuar.
# U tira un 3
# Puntos acumulados en esta ronda: 5
# U decide continuar.
# U tira un 1
# U pierde los puntos de esta ronda.
# U suma 0 puntos. Total acumulado: 36
#
# Turno de V. Estrategia: EstrategiaMedia
# V tira un 3
# Puntos acumulados en esta ronda: 3
# V decide continuar.
# V tira un 1
# V pierde los puntos de esta ronda.
# V suma 0 puntos. Total acumulado: 0
#
# Turno de W. Estrategia: EstrategiaConservadora
# W tira un 2
# Puntos acumulados en esta ronda: 2
# W decide continuar.
# W tira un 2
# Puntos acumulados en esta ronda: 4
# W decide continuar.
# W tira un 6
# Puntos acumulados en esta ronda: 10
# W decide detenerse.
# W suma 10 puntos. Total acumulado: 24
#
# Turno de X. Estrategia: EstrategiaConservadora
# X tira un 1
# X pierde los puntos de esta ronda.
# X suma 0 puntos. Total acumulado: 12
#
# Turno de Y. Estrategia: EstrategiaConservadora
# Y tira un 2
# Puntos acumulados en esta ronda: 2
# Y decide continuar.
# Y tira un 2
# Puntos acumulados en esta ronda: 4
# Y decide continuar.
# Y tira un 4
# Puntos acumulados en esta ronda: 8
# Y decide continuar.
# Y tira un 4
# Puntos acumulados en esta ronda: 12
# Y decide detenerse.
# Y suma 12 puntos. Total acumulado: 24
#
# Turno de Z. Estrategia: EstrategiaConservadora
# Z tira un 3
# Puntos acumulados en esta ronda: 3
# Z decide continuar.
# Z tira un 6
# Puntos acumulados en esta ronda: 9
# Z decide continuar.
# Z tira un 6
# Puntos acumulados en esta ronda: 15
# Z decide detenerse.
# Z suma 15 puntos. Total acumulado: 52
#
# --- Ronda 5 ---
#
# Turno de A. Estrategia: EstrategiaAgresiva
# A tira un 2
# Puntos acumulados en esta ronda: 2
# A decide continuar.
# A tira un 2
# Puntos acumulados en esta ronda: 4
# A decide continuar.
# A tira un 6
# Puntos acumulados en esta ronda: 10
# A decide continuar.
# A tira un 4
# Puntos acumulados en esta ronda: 14
# A decide continuar.
# A tira un 6
# Puntos acumulados en esta ronda: 20
# A decide continuar.
# A tira un 5
# Puntos acumulados en esta ronda: 25
# A decide continuar.
# A tira un 1
# A pierde los puntos de esta ronda.
# A suma 0 puntos. Total acumulado: 10
#
# Turno de B. Estrategia: EstrategiaConservadora
# B tira un 3
# Puntos acumulados en esta ronda: 3
# B decide continuar.
# B tira un 2
# Puntos acumulados en esta ronda: 5
# B decide continuar.
# B tira un 3
# Puntos acumulados en esta ronda: 8
# B decide continuar.
# B tira un 4
# Puntos acumulados en esta ronda: 12
# B decide detenerse.
# B suma 12 puntos. Total acumulado: 39
#
# Turno de C. Estrategia: EstrategiaConservadora
# C tira un 2
# Puntos acumulados en esta ronda: 2
# C decide continuar.
# C tira un 5
# Puntos acumulados en esta ronda: 7
# C decide continuar.
# C tira un 5
# Puntos acumulados en esta ronda: 12
# C decide detenerse.
# C suma 12 puntos. Total acumulado: 56
#
# Turno de D. Estrategia: EstrategiaConservadora
# D tira un 4
# Puntos acumulados en esta ronda: 4
# D decide continuar.
# D tira un 2
# Puntos acumulados en esta ronda: 6
# D decide continuar.
# D tira un 6
# Puntos acumulados en esta ronda: 12
# D decide detenerse.
# D suma 12 puntos. Total acumulado: 46
#
# Turno de E. Estrategia: EstrategiaConservadora
# E tira un 2
# Puntos acumulados en esta ronda: 2
# E decide continuar.
# E tira un 1
# E pierde los puntos de esta ronda.
# E suma 0 puntos. Total acumulado: 28
#
# Turno de F. Estrategia: EstrategiaAgresiva
# F tira un 4
# Puntos acumulados en esta ronda: 4
# F decide continuar.
# F tira un 2
# Puntos acumulados en esta ronda: 6
# F decide continuar.
# F tira un 4
# Puntos acumulados en esta ronda: 10
# F decide continuar.
# F tira un 6
# Puntos acumulados en esta ronda: 16
# F decide continuar.
# F tira un 4
# Puntos acumulados en esta ronda: 20
# F decide continuar.
# F tira un 2
# Puntos acumulados en esta ronda: 22
# F decide continuar.
# F tira un 5
# Puntos acumulados en esta ronda: 27
# F decide continuar.
# F tira un 2
# Puntos acumulados en esta ronda: 29
# F decide continuar.
# F tira un 6
# Puntos acumulados en esta ronda: 35
# F decide continuar.
# F tira un 4
# Puntos acumulados en esta ronda: 39
# F decide continuar.
# F tira un 3
# Puntos acumulados en esta ronda: 42
# F decide detenerse.
# F suma 42 puntos. Total acumulado: 64
#
# Turno de G. Estrategia: EstrategiaConservadora
# G tira un 6
# Puntos acumulados en esta ronda: 6
# G decide continuar.
# G tira un 4
# Puntos acumulados en esta ronda: 10
# G decide detenerse.
# G suma 10 puntos. Total acumulado: 57
#
# Turno de H. Estrategia: EstrategiaConservadora
# H tira un 5
# Puntos acumulados en esta ronda: 5
# H decide continuar.
# H tira un 3
# Puntos acumulados en esta ronda: 8
# H decide continuar.
# H tira un 3
# Puntos acumulados en esta ronda: 11
# H decide detenerse.
# H suma 11 puntos. Total acumulado: 60
#
# Turno de I. Estrategia: EstrategiaConservadora
# I tira un 5
# Puntos acumulados en esta ronda: 5
# I decide continuar.
# I tira un 2
# Puntos acumulados en esta ronda: 7
# I decide continuar.
# I tira un 2
# Puntos acumulados en esta ronda: 9
# I decide continuar.
# I tira un 3
# Puntos acumulados en esta ronda: 12
# I decide detenerse.
# I suma 12 puntos. Total acumulado: 57
#
# Turno de J. Estrategia: EstrategiaAgresiva
# J tira un 3
# Puntos acumulados en esta ronda: 3
# J decide continuar.
# J tira un 3
# Puntos acumulados en esta ronda: 6
# J decide continuar.
# J tira un 2
# Puntos acumulados en esta ronda: 8
# J decide continuar.
# J tira un 5
# Puntos acumulados en esta ronda: 13
# J decide continuar.
# J tira un 1
# J pierde los puntos de esta ronda.
# J suma 0 puntos. Total acumulado: 19
#
# Turno de K. Estrategia: EstrategiaAgresiva
# K tira un 6
# Puntos acumulados en esta ronda: 6
# K decide continuar.
# K tira un 6
# Puntos acumulados en esta ronda: 12
# K decide continuar.
# K tira un 1
# K pierde los puntos de esta ronda.
# K suma 0 puntos. Total acumulado: 24
#
# Turno de L. Estrategia: EstrategiaAgresiva
# L tira un 3
# Puntos acumulados en esta ronda: 3
# L decide continuar.
# L tira un 2
# Puntos acumulados en esta ronda: 5
# L decide continuar.
# L tira un 6
# Puntos acumulados en esta ronda: 11
# L decide continuar.
# L tira un 6
# Puntos acumulados en esta ronda: 17
# L decide continuar.
# L tira un 2
# Puntos acumulados en esta ronda: 19
# L decide continuar.
# L tira un 5
# Puntos acumulados en esta ronda: 24
# L decide continuar.
# L tira un 3
# Puntos acumulados en esta ronda: 27
# L decide continuar.
# L tira un 6
# Puntos acumulados en esta ronda: 33
# L decide continuar.
# L tira un 6
# Puntos acumulados en esta ronda: 39
# L decide continuar.
# L tira un 3
# Puntos acumulados en esta ronda: 42
# L decide detenerse.
# L suma 42 puntos. Total acumulado: 53
#
# Turno de M. Estrategia: EstrategiaAgresiva
# M tira un 5
# Puntos acumulados en esta ronda: 5
# M decide continuar.
# M tira un 1
# M pierde los puntos de esta ronda.
# M suma 0 puntos. Total acumulado: 12
#
# Turno de N. Estrategia: EstrategiaConservadora
# N tira un 1
# N pierde los puntos de esta ronda.
# N suma 0 puntos. Total acumulado: 42
#
# Turno de O. Estrategia: EstrategiaConservadora
# O tira un 6
# Puntos acumulados en esta ronda: 6
# O decide continuar.
# O tira un 2
# Puntos acumulados en esta ronda: 8
# O decide continuar.
# O tira un 3
# Puntos acumulados en esta ronda: 11
# O decide detenerse.
# O suma 11 puntos. Total acumulado: 47
#
# Turno de P. Estrategia: EstrategiaConservadora
# P tira un 4
# Puntos acumulados en esta ronda: 4
# P decide continuar.
# P tira un 2
# Puntos acumulados en esta ronda: 6
# P decide continuar.
# P tira un 6
# Puntos acumulados en esta ronda: 12
# P decide detenerse.
# P suma 12 puntos. Total acumulado: 38
#
# Turno de Q. Estrategia: EstrategiaConservadora
# Q tira un 6
# Puntos acumulados en esta ronda: 6
# Q decide continuar.
# Q tira un 5
# Puntos acumulados en esta ronda: 11
# Q decide detenerse.
# Q suma 11 puntos. Total acumulado: 44
#
# Turno de R. Estrategia: EstrategiaAgresiva
# R tira un 6
# Puntos acumulados en esta ronda: 6
# R decide continuar.
# R tira un 1
# R pierde los puntos de esta ronda.
# R suma 0 puntos. Total acumulado: 25
#
# Turno de S. Estrategia: EstrategiaAgresiva
# S tira un 6
# Puntos acumulados en esta ronda: 6
# S decide continuar.
# S tira un 5
# Puntos acumulados en esta ronda: 11
# S decide continuar.
# S tira un 1
# S pierde los puntos de esta ronda.
# S suma 0 puntos. Total acumulado: 25
#
# Turno de T. Estrategia: EstrategiaAgresiva
# T tira un 5
# Puntos acumulados en esta ronda: 5
# T decide continuar.
# T tira un 3
# Puntos acumulados en esta ronda: 8
# T decide continuar.
# T tira un 1
# T pierde los puntos de esta ronda.
# T suma 0 puntos. Total acumulado: 25
#
# Turno de U. Estrategia: EstrategiaConservadora
# U tira un 3
# Puntos acumulados en esta ronda: 3
# U decide continuar.
# U tira un 6
# Puntos acumulados en esta ronda: 9
# U decide continuar.
# U tira un 2
# Puntos acumulados en esta ronda: 11
# U decide detenerse.
# U suma 11 puntos. Total acumulado: 47
#
# Turno de V. Estrategia: EstrategiaAgresiva
# V tira un 3
# Puntos acumulados en esta ronda: 3
# V decide continuar.
# V tira un 3
# Puntos acumulados en esta ronda: 6
# V decide continuar.
# V tira un 4
# Puntos acumulados en esta ronda: 10
# V decide continuar.
# V tira un 3
# Puntos acumulados en esta ronda: 13
# V decide continuar.
# V tira un 1
# V pierde los puntos de esta ronda.
# V suma 0 puntos. Total acumulado: 0
#
# Turno de W. Estrategia: EstrategiaAgresiva
# W tira un 4
# Puntos acumulados en esta ronda: 4
# W decide continuar.
# W tira un 4
# Puntos acumulados en esta ronda: 8
# W decide continuar.
# W tira un 3
# Puntos acumulados en esta ronda: 11
# W decide continuar.
# W tira un 6
# Puntos acumulados en esta ronda: 17
# W decide continuar.
# W tira un 5
# Puntos acumulados en esta ronda: 22
# W decide continuar.
# W tira un 6
# Puntos acumulados en esta ronda: 28
# W decide continuar.
# W tira un 2
# Puntos acumulados en esta ronda: 30
# W decide continuar.
# W tira un 1
# W pierde los puntos de esta ronda.
# W suma 0 puntos. Total acumulado: 24
#
# Turno de X. Estrategia: EstrategiaAgresiva
# X tira un 5
# Puntos acumulados en esta ronda: 5
# X decide continuar.
# X tira un 4
# Puntos acumulados en esta ronda: 9
# X decide continuar.
# X tira un 3
# Puntos acumulados en esta ronda: 12
# X decide continuar.
# X tira un 3
# Puntos acumulados en esta ronda: 15
# X decide continuar.
# X tira un 4
# Puntos acumulados en esta ronda: 19
# X decide continuar.
# X tira un 2
# Puntos acumulados en esta ronda: 21
# X decide continuar.
# X tira un 1
# X pierde los puntos de esta ronda.
# X suma 0 puntos. Total acumulado: 12
#
# Turno de Y. Estrategia: EstrategiaAgresiva
# Y tira un 3
# Puntos acumulados en esta ronda: 3
# Y decide continuar.
# Y tira un 3
# Puntos acumulados en esta ronda: 6
# Y decide continuar.
# Y tira un 1
# Y pierde los puntos de esta ronda.
# Y suma 0 puntos. Total acumulado: 24
#
# Turno de Z. Estrategia: EstrategiaConservadora
# Z tira un 2
# Puntos acumulados en esta ronda: 2
# Z decide continuar.
# Z tira un 1
# Z pierde los puntos de esta ronda.
# Z suma 0 puntos. Total acumulado: 52
#
# --- Resultados Finales ---
# 1. F: 64 puntos
# 2. H: 60 puntos
# 3. G: 57 puntos
# 4. I: 57 puntos
# 5. C: 56 puntos
# 6. L: 53 puntos
# 7. Z: 52 puntos
# 8. O: 47 puntos
# 9. U: 47 puntos
# 10. D: 46 puntos
# 11. Q: 44 puntos
# 12. N: 42 puntos
# 13. B: 39 puntos
# 14. P: 38 puntos
# 15. E: 28 puntos
# 16. R: 25 puntos
# 17. S: 25 puntos
# 18. T: 25 puntos
# 19. K: 24 puntos
# 20. W: 24 puntos
# 21. Y: 24 puntos
# 22. J: 19 puntos
# 23. M: 12 puntos
# 24. X: 12 puntos
# 25. A: 10 puntos
# 26. V: 0 puntos
#
# ¡F gana con 64 puntos!
